# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/langchain-ai/langchain-academy/blob/main/module-2/chatbot-external-memory.ipynb) [![Open in LangChain Academy](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66e9eba12c7b7688aa3dbb5e_LCA-badge-green.svg)](https://academy.langchain.com/courses/take/intro-to-langgraph/lessons/58239440-lesson-6-chatbot-w-summarizing-messages-and-external-memory)

# %% [markdown]
# # Chatbot with message summarization & external DB memory
#
# ## Review
#
# We've covered how to customize graph state schema and reducer.
#
# We've also shown a number of tricks for trimming or filtering messages in graph state.
#
# We've used these concepts in a Chatbot with memory that produces a running summary of the conversation.
#
# ## Goals
#
# But, what if we want our Chatbot to have memory that persists indefinitely?
#
# Now, we'll introduce some more advanced checkpointers that support external databases.
#
# Here, we'll show how to use [Sqlite as a checkpointer](https://langchain-ai.github.io/langgraph/concepts/low_level/#checkpointer), but other checkpointers, such as [Postgres](https://langchain-ai.github.io/langgraph/how-tos/persistence_postgres/) are available!

# %%
# %%capture --no-stderr
# %pip install --quiet -U langgraph-checkpoint-sqlite langchain_core langgraph langchain_openai

# %% [markdown]
# ## Setup the keys

# %%
import os
from dotenv import load_dotenv

# Load variables from .env
load_dotenv(dotenv_path="I:\\.env")
# Out:
# True

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings, ChatGoogleGenerativeAI
from langchain_community.vectorstores import FAISS

# %%
# LLM with function call
model = ChatGoogleGenerativeAI(model="gemini-1.5-flash", temperature=0.3) # Try using gemini-pro-vision
# Create embeddings using a Google Generative AI model
embedding = GoogleGenerativeAIEmbeddings(model="models/embedding-001")

model.invoke('where is delhi ?')
# Out:
# AIMessage(content="Delhi is located in **north India**.  More specifically, it's in the **National Capital Territory of Delhi**, a federally controlled territory.  It's situated on the **Ganges-Yamuna plains**.", additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-1.5-flash', 'safety_ratings': []}, id='run-5047d29e-bde9-460d-974c-b4f8b1226e77-0', usage_metadata={'input_tokens': 4, 'output_tokens': 45, 'total_tokens': 49, 'input_token_details': {'cache_read': 0}})

# %% [markdown]
# ## Sqlite
#
# A good starting point here is the [SqliteSaver checkpointer](https://langchain-ai.github.io/langgraph/concepts/low_level/#checkpointer).
#
# Sqlite is a [small, fast, highly popular](https://x.com/karpathy/status/1819490455664685297) SQL database.
#
# If we supply `":memory:"` it creates an in-memory Sqlite database.

# %%
import sqlite3
# In memory
conn = sqlite3.connect(":memory:", check_same_thread = False)

# %% [markdown]
# But, if we supply a db path, then it will create a database for us!

# %%
# pull file if it doesn't exist and connect to local db
# !mkdir -p state_db && [ ! -f state_db/example.db ] && wget -P state_db https://github.com/langchain-ai/langchain-academy/raw/main/module-2/state_db/example.db

db_path = "state_db/example.db"
conn = sqlite3.connect(db_path, check_same_thread=False)
# Out:
# A subdirectory or file -p already exists.
# Error occurred while processing: -p.
# A subdirectory or file state_db already exists.
# Error occurred while processing: state_db.

# %%
# Here is our checkpointer 
from langgraph.checkpoint.sqlite import SqliteSaver
memory = SqliteSaver(conn)

# %% [markdown]
# Let's re-define our chatbot.

# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import SystemMessage, HumanMessage, RemoveMessage

from langgraph.graph import END
from langgraph.graph import MessagesState


class State(MessagesState):
    summary: str

# Define the logic to call the model
def call_model(state: State):
    
    # Get summary if it exists
    summary = state.get("summary", "")

    # If there is summary, then we add it
    if summary:
        
        # Add summary to system message
        system_message = f"Summary of conversation earlier: {summary}"

        # Append summary to any newer messages
        messages = [SystemMessage(content=system_message)] + state["messages"]
    
    else:
        messages = state["messages"]
    
    response = model.invoke(messages)
    return {"messages": response}

def summarize_conversation(state: State):
    
    # First, we get any existing summary
    summary = state.get("summary", "")

    # Create our summarization prompt 
    if summary:
        
        # A summary already exists
        summary_message = (
            f"This is summary of the conversation to date: {summary}\n\n"
            "Extend the summary by taking into account the new messages above:"
        )
        
    else:
        summary_message = "Create a summary of the conversation above:"

    # Add prompt to our history
    messages = state["messages"] + [HumanMessage(content=summary_message)]
    response = model.invoke(messages)
    
    # Delete all but the 2 most recent messages
    delete_messages = [RemoveMessage(id=m.id) for m in state["messages"][:-2]]
    return {"summary": response.content, "messages": delete_messages}

# Determine whether to end or summarize the conversation
def should_continue(state: State):
    
    """Return the next node to execute."""
    
    messages = state["messages"]
    
    # If there are more than six messages, then we summarize the conversation
    if len(messages) > 6:
        return "summarize_conversation"
    
    # Otherwise we can just end
    return END

# %% [markdown]
# Now, we just re-compile with our sqlite checkpointer.

# %%
from IPython.display import Image, display
from langgraph.graph import StateGraph, START

# Define a new graph
workflow = StateGraph(State)
workflow.add_node("conversation", call_model)
workflow.add_node(summarize_conversation)

# Set the entrypoint as conversation
workflow.add_edge(START, "conversation")
workflow.add_conditional_edges("conversation", should_continue)
workflow.add_edge("summarize_conversation", END)

# Compile
graph = workflow.compile(checkpointer=memory)
display(Image(graph.get_graph().draw_mermaid_png()))

# %% [markdown]
# Now, we can invoke the graph several times.

# %%
# Create a thread
config = {"configurable": {"thread_id": "1"}}

# Start conversation
input_message = HumanMessage(content="hi! I'm Lance")
output = graph.invoke({"messages": [input_message]}, config) 
for m in output['messages'][-1:]:
    m.pretty_print()

input_message = HumanMessage(content="what's my name?")
output = graph.invoke({"messages": [input_message]}, config) 
for m in output['messages'][-1:]:
    m.pretty_print()

input_message = HumanMessage(content="i like the 49ers!")
output = graph.invoke({"messages": [input_message]}, config) 
for m in output['messages'][-1:]:
    m.pretty_print()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       2 config = {"configurable": {"thread_id": "sesa679075"}}
#       4 # Start conversation
# ----> 5 input_message = HumanMessage(content="hi! my name is Bunty. I'm from schneider sales !")
#       6 output = graph.invoke({"messages": [input_message]}, config)
#       7 for m in output['messages'][-2:]:
#
# NameError: name 'HumanMessage' is not defined

# %% [markdown]
# Let's confirm that our state is saved locally.

# %%
config = {"configurable": {"thread_id": "1"}}
graph_state = graph.get_state(config)
graph_state
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content="hi! I'm Lance", additional_kwargs={}, response_metadata={}, id='a0dc3d58-7882-42b2-8952-48db856bb489'), AIMessage(content='Hi Lance!  We\'ve spoken before.  It\'s nice to "see" you again.  Since you like the 49ers,  would you like to talk about a specific aspect of the team, like a particular player, a memorable season, or their current prospects?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-1.5-flash', 'safety_ratings': []}, id='run-467a266c-b9c8-441a-ac68-8788f113af28-0', usage_metadata={'input_tokens': 298, 'output_tokens': 61, 'total_tokens': 359, 'input_token_details': {'cache_read': 0}}), HumanMessage(content="what's my name?", additional_kwargs={}, response_metadata={}, id='1dd86d0a-fac3-4ffe-a3de-5f77c32e3339'), AIMessage(content='Your name is Lance.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-1.5-flash', 'safety_ratings': []}, id='run-ca5de574-f489-44e7-9b33-3e48fb3d0dbb-0', usage_metadata={'input_tokens': 311, 'output_tokens': 6, 'total_tokens': 317, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='i like the 49ers!', additional_kwargs={}, response_metadata={}, id='e7ff3973-d661-498f-88e3-b08d53aae457'), AIMessage(content="Great!  I remember you mentioned that before.  Is there anything in particular you'd like to discuss about the 49ers?  Perhaps a favorite player, a memorable game, or their chances this season?", additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-1.5-flash', 'safety_ratings': []}, id='run-b5198ab2-9ebe-4cfd-b813-f21292dede10-0', usage_metadata={'input_tokens': 324, 'output_tokens': 46, 'total_tokens': 370, 'input_token_details': {'cache_read': 0}})], 'summary': 'This is a summary of the conversation to date:\n\nLance repeatedly introduced himself multiple times, stating "Hi! I\'m Lance" on several occasions.  He expressed his fondness for the San Francisco 49ers football team. The AI assistant acknowledged Lance\'s name each time and repeatedly showed willingness to discuss the 49ers, offering to talk about various aspects of the team such as their history, current roster, or memorable games.  The conversation was brief, repetitive, and lacked substantive engagement beyond Lance\'s repeated self-introduction and his single statement of liking the 49ers. The AI\'s attempts to steer the conversation towards a discussion of the 49ers were largely unsuccessful due to Lance\'s lack of further input beyond reiterating his name and his initial positive statement about the team. The conversation demonstrates a clear communication gap, with Lance seemingly unable or unwilling to engage in a more developed discussion.  The AI successfully remembered Lance\'s name and previous statements across multiple interactions, demonstrating a persistent memory of the conversation history.  However,  the lack of substantial contribution from Lance limited the overall depth and length of the exchange.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f025fa8-d2ca-655e-802b-dc283424b180'}}, metadata={'source': 'loop', 'writes': {'conversation': {'messages': AIMessage(content="Great!  I remember you mentioned that before.  Is there anything in particular you'd like to discuss about the 49ers?  Perhaps a favorite player, a memorable game, or their chances this season?", additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-1.5-flash', 'safety_ratings': []}, id='run-b5198ab2-9ebe-4cfd-b813-f21292dede10-0', usage_metadata={'input_tokens': 324, 'output_tokens': 46, 'total_tokens': 370, 'input_token_details': ...

# %% [markdown]
# ### Persisting state
#
# Using database like Sqlite means state is persisted!
#
# For example, we can re-start the notebook kernel and see that we can still load from Sqlite DB on disk.

# %%
# Create a thread
config = {"configurable": {"thread_id": "1"}}
graph_state = graph.get_state(config)
graph_state
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content="hi! I'm Lance", additional_kwargs={}, response_metadata={}, id='a0dc3d58-7882-42b2-8952-48db856bb489'), AIMessage(content='Hi Lance!  We\'ve spoken before.  It\'s nice to "see" you again.  Since you like the 49ers,  would you like to talk about a specific aspect of the team, like a particular player, a memorable season, or their current prospects?', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-1.5-flash', 'safety_ratings': []}, id='run-467a266c-b9c8-441a-ac68-8788f113af28-0', usage_metadata={'input_tokens': 298, 'output_tokens': 61, 'total_tokens': 359, 'input_token_details': {'cache_read': 0}}), HumanMessage(content="what's my name?", additional_kwargs={}, response_metadata={}, id='1dd86d0a-fac3-4ffe-a3de-5f77c32e3339'), AIMessage(content='Your name is Lance.', additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-1.5-flash', 'safety_ratings': []}, id='run-ca5de574-f489-44e7-9b33-3e48fb3d0dbb-0', usage_metadata={'input_tokens': 311, 'output_tokens': 6, 'total_tokens': 317, 'input_token_details': {'cache_read': 0}}), HumanMessage(content='i like the 49ers!', additional_kwargs={}, response_metadata={}, id='e7ff3973-d661-498f-88e3-b08d53aae457'), AIMessage(content="Great!  I remember you mentioned that before.  Is there anything in particular you'd like to discuss about the 49ers?  Perhaps a favorite player, a memorable game, or their chances this season?", additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-1.5-flash', 'safety_ratings': []}, id='run-b5198ab2-9ebe-4cfd-b813-f21292dede10-0', usage_metadata={'input_tokens': 324, 'output_tokens': 46, 'total_tokens': 370, 'input_token_details': {'cache_read': 0}})], 'summary': 'This is a summary of the conversation to date:\n\nLance repeatedly introduced himself multiple times, stating "Hi! I\'m Lance" on several occasions.  He expressed his fondness for the San Francisco 49ers football team. The AI assistant acknowledged Lance\'s name each time and repeatedly showed willingness to discuss the 49ers, offering to talk about various aspects of the team such as their history, current roster, or memorable games.  The conversation was brief, repetitive, and lacked substantive engagement beyond Lance\'s repeated self-introduction and his single statement of liking the 49ers. The AI\'s attempts to steer the conversation towards a discussion of the 49ers were largely unsuccessful due to Lance\'s lack of further input beyond reiterating his name and his initial positive statement about the team. The conversation demonstrates a clear communication gap, with Lance seemingly unable or unwilling to engage in a more developed discussion.  The AI successfully remembered Lance\'s name and previous statements across multiple interactions, demonstrating a persistent memory of the conversation history.  However,  the lack of substantial contribution from Lance limited the overall depth and length of the exchange.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f025fa8-d2ca-655e-802b-dc283424b180'}}, metadata={'source': 'loop', 'writes': {'conversation': {'messages': AIMessage(content="Great!  I remember you mentioned that before.  Is there anything in particular you'd like to discuss about the 49ers?  Perhaps a favorite player, a memorable game, or their chances this season?", additional_kwargs={}, response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-1.5-flash', 'safety_ratings': []}, id='run-b5198ab2-9ebe-4cfd-b813-f21292dede10-0', usage_metadata={'input_tokens': 324, 'output_tokens': 46, 'total_tokens': 370, 'input_token_details': ...

# %% [markdown]
# ## LangGraph Studio
#
# **⚠️ DISCLAIMER**
#
# Since the filming of these videos, we've updated Studio so that it can be run locally and opened in your browser. This is now the preferred way to run Studio (rather than using the Desktop App as shown in the video). See documentation [here](https://langchain-ai.github.io/langgraph/concepts/langgraph_studio/#local-development-server) on the local development server and [here](https://langchain-ai.github.io/langgraph/how-tos/local-studio/#run-the-development-server). To start the local development server, run the following command in your terminal in the `/studio` directory in this module:
#
# ```
# langgraph dev
# ```
#
# You should see the following output:
# ```
# - 🚀 API: http://127.0.0.1:2024
# - 🎨 Studio UI: https://smith.langchain.com/studio/?baseUrl=http://127.0.0.1:2024
# - 📚 API Docs: http://127.0.0.1:2024/docs
# ```
#
# Open your browser and navigate to the Studio UI: `https://smith.langchain.com/studio/?baseUrl=http://127.0.0.1:2024`.
